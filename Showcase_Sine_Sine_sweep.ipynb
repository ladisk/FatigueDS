# %%
import numpy as np
import FatigueDS
import matplotlib.pyplot as plt

# %% [markdown]
# # Showcase: Sine and Sine-Sweep Signal Evaluation

# %% [markdown]
# ## Spectrum object

# %% [markdown]
# Spectrum object contains data, required for the calculation of extreme response spectrum (ERS) and fatigue damage spectrum (FDS). It enables calculation for sine and sine-sweep signals.

# %% [markdown]
# ### Instantiate Class

# %% [markdown]
# Identically to the case of random signal evaluation (Showcase Random.ipynb) the class for sine and sine-sweep signal evaluation is instantiated with inputs:
# - `freq_data`: tuple containing (f0_start, f0_stop, f0_step) [Hz] or a frequency vector, defining the range where the ERS and FDS will be calculated
# -  damping ratio `damp` or damping Q-factor `Q`

# %%
load_spectrum_1 = FatigueDS.Spectrum(freq_data=(0, 2000, 5), damp=0.1)  # sine

load_spectrum_2 = FatigueDS.Spectrum(freq_data=(0, 2000, 5), damp=0.1)  # sine sweep

# %% [markdown]
# ### Set load

# %% [markdown]
# Random load is defined with the `set_sine_load` and `set_sine_sweep_load` methods

# %%
load_spectrum_1.set_sine_load(sine_freq=500, amp=10, t_total=3600)  # t_total is only needed for fds calculation

# %%
load_spectrum_2.set_sine_sweep_load(const_amp=[5, 10, 20], const_f_range=[20, 100, 500, 1000], exc_type='acc', sweep_type='log', sweep_rate=1)

# %% [markdown]
# ### Get ERS and FDS

# %% [markdown]
# ERS and FDS spectra are calculated:

# %%
load_spectrum_1.get_ers()
load_spectrum_2.get_ers()

# %%
# 'get_fds' method requires material fatigue parameters: k, C and proportionality constant p

load_spectrum_1.get_fds(k=5, C=1, p=1)
load_spectrum_2.get_fds(k=5, C=1, p=1)

# %% [markdown]
# Results can be directly accessed as `ers` and `fds` atributes of the Spectrum object. Frequency vector can be accessed as `f0_range` atribute.

# %%
# load_spectrum_1.ers 
# load_spectrum_1.fds
# load_spectrum_1.f0_range

# %% [markdown]
# ### Plot results

# %%
load_spectrum_1.plot_ers(label='sine')
load_spectrum_1.plot_fds(label='sine')

# %%
load_spectrum_2.plot_ers(label='sine sweep')
load_spectrum_2.plot_fds(label='sine sweep')
